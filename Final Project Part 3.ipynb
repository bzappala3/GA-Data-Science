# %%
# Imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# This allows plots to appear directly in the notebook.
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
# Read Rate data into a DataFrame.
rate = pd.read_csv('/Users/Barbara/Desktop/GA Data Science/Rate_PUF.csv')
rate = rate.sample(frac=.1)
rate.head()
# Out:
#          BusinessYear StateCode  IssuerId SourceName           ImportDate  \
# 2757128          2017        OH     80627      SERFF  2016-08-20 11:23:22
# 60734            2017        AL     68707       HIOS  2016-05-16 23:14:35
# 167225           2017        FL     16842       HIOS  2016-09-14 22:21:51
# 2320950          2017        MI     15560      SERFF  2017-04-25 20:15:31
# 2542863          2017        NE     45550      SERFF  2016-09-28 04:33:02
#
#          FederalTIN RateEffectiveDate RateExpirationDate          PlanId  \
# 2757128  34-0648820        2017-01-01         2017-12-31  80627OH0150043
# 60734    93-0242990        2017-01-01         2017-12-31  68707AL0040002
# 167225   59-2015694        2017-01-01         2017-12-31  16842FL0070122
# 2320950  38-2069753        2017-07-01         2017-09-30  15560MI0450002
# 2542863  47-0685003        2017-01-01         2017-12-31  45550NE0090001
#
#            RatingAreaId               ...               Age IndividualRate  \
# 2757128   Rating Area 3               ...                48          32.38
# 60734    Rating Area 10               ...                34           0.00
# 167225   Rating Area 33               ...                25         296.64
# 2320950   Rating Area 2               ...                30          23.29
# 2542863   Rating Area 1               ...                57           0.00
#
#          IndividualTobaccoRate  Couple  PrimarySubscriberAndOneDependent  \
# 2757128                    NaN     NaN                               NaN
# 60734                      NaN     NaN                               NaN
# 167225                  326.31     NaN                               NaN
# 2320950                    NaN     NaN                               NaN
# 2542863                    NaN     NaN                               NaN
#
#          PrimarySubscriberAndTwoDependents  \
# 2757128                                NaN
# 60734                                  NaN
# 167225                                 NaN
# 2320950                                NaN
# 2542863                                NaN
#
#          PrimarySubscriberAndThreeOrMoreDependents  CoupleAndOneDependent  \
# 2757128                                        NaN                    NaN
# 60734                                          NaN                    NaN
# 167225                                         NaN                    NaN
# 2320950                                        NaN                    NaN
# 2542863                                        NaN                    NaN
#
#          CoupleAndTwoDependents  CoupleAndThreeOrMoreDependents
# 2757128                     NaN                             NaN
# 60734                       NaN                             NaN
# 167225                      NaN                             NaN
# 2320950                     NaN                             NaN
# 2542863                     NaN                             NaN
#
# [5 rows x 21 columns]

# %%
#Look at number of rows and columns in Rates
rate.shape
# Out:
# (309876, 21)

# %%
#Look at column types in rates
rate.dtypes
# Out:
# BusinessYear                                   int64
# StateCode                                     object
# IssuerId                                       int64
# SourceName                                    object
# ImportDate                                    object
# FederalTIN                                    object
# RateEffectiveDate                             object
# RateExpirationDate                            object
# PlanId                                        object
# RatingAreaId                                  object
# Tobacco                                       object
# Age                                           object
# IndividualRate                               float64
# IndividualTobaccoRate                        float64
# Couple                                       float64
# PrimarySubscriberAndOneDependent             float64
# PrimarySubscriberAndTwoDependents            float64
# PrimarySubscriberAndThreeOrMoreDependents    float64
# CoupleAndOneDependent                        float64
# CoupleAndTwoDependents                       float64
# CoupleAndThreeOrMoreDependents               float64
# dtype: object

# %%
#Look at top, frequency for strings and min, max and mean for all columns in rate
rate.describe(include='all')
# Out:
#         BusinessYear StateCode       IssuerId SourceName           ImportDate  \
# count       309876.0    309876  309876.000000     309876               309876
# unique           NaN        39            NaN          3                  109
# top              NaN        FL            NaN       HIOS  2016-07-01 08:12:23
# freq             NaN     43022            NaN     194183                27085
# mean          2017.0       NaN   53606.076734        NaN                  NaN
# std              0.0       NaN   28428.582892        NaN                  NaN
# min           2017.0       NaN   10046.000000        NaN                  NaN
# 25%           2017.0       NaN   29276.000000        NaN                  NaN
# 50%           2017.0       NaN   47973.000000        NaN                  NaN
# 75%           2017.0       NaN   83761.000000        NaN                  NaN
# max           2017.0       NaN   99969.000000        NaN                  NaN
#
#         FederalTIN RateEffectiveDate RateExpirationDate          PlanId  \
# count       309876            309876             309876          309876
# unique         226                 4                  4            6591
# top     47-0397286        2017-01-01         2017-12-31  98534FL0240001
# freq         22354            201524             201557            1289
# mean           NaN               NaN                NaN             NaN
# std            NaN               NaN                NaN             NaN
# min            NaN               NaN                NaN             NaN
# 25%            NaN               NaN                NaN             NaN
# 50%            NaN               NaN                NaN             NaN
# 75%            NaN               NaN                NaN             NaN
# max            NaN               NaN                NaN             NaN
#
#          RatingAreaId               ...                   Age IndividualRate  \
# count          309876               ...                309876  309876.000000
# unique             67               ...                    47            NaN
# top     Rating Area 1               ...                    62            NaN
# freq            23616               ...                  6858            NaN
# mean              NaN               ...                   NaN     331.289354
# std               NaN               ...                   NaN     646.998936
# min               NaN               ...                   NaN       0.000000
# 25%               NaN               ...                   NaN      25.120000
# 50%               NaN               ...                   NaN     206.995000
# 75%               NaN               ...                   NaN     491.410000
# max               NaN               ...                   NaN    9999.000000
#
#         IndividualTobaccoRate      Couple  PrimarySubscriberAndOneDependent  \
# count            64522.000000  350.000000                        350.000000
# unique                    NaN         NaN                               NaN
# top                       NaN         NaN                               NaN
# freq                      NaN         NaN                               NaN
# mean               618.214237   51.951057                         59.707143
# std                333.054760   34.521546                         41.188292
# min                 88.640000    0.000000                          0.000000
# 25%                378.440000   27.630000                         29.300000
# 50%                521.520000   34.910000                         39.050000
# 75%                784.477500   86.000000                         95.727500
# max               2995.680000  144.410000                        167.030000
#
#         PrimarySubscriberAndTwoDependents  \
# count                          350.000000
# unique                                NaN
# top                                   NaN
# freq                                  NaN
# mean                            64.655257
# std                             44.207157
# min                              0.000000
# 25%                             29.300000
# 50%                             48.220000
# 75%                            107.522500
# max                            168.360000
#
#         PrimarySubscriberAndThreeOrMoreDependents  CoupleAndOneDependent  \
# count                                  350.000000             350.000000
# unique                                        NaN                    NaN
# top                                           NaN                    NaN
# freq                                          NaN                    NaN
# mean                                    68.938829              83.128429
# std                                     50.052993              67.572582
# min                                      0.000000               0.000000
# 25%                                     29.300000              29.300000
# 50%                                     48.220000              50.540000
# 75%                                    113.357500             145.855000
# max                                    231.010000             256.010000
#
#         CoupleAndTwoDependents  CoupleAndThreeOrMoreDependents
# count               350.000000                      350.000000
# unique                     NaN                             NaN
# top                        NaN                             NaN
# freq                       NaN                             NaN
# mean                 87.371229                       91.605514
# std                  69.453977                       73.444313
# min                   0.000000                        0.000000
# 25%                  29.300000                       29.300000
# 50%                  62.920000                       63.390000
# 75%                 155.620000                      164.260000
# max                 256.010000                      274.050000
#
# [11 rows x 21 columns]

# %% [markdown]
# I noticed that Individual rate min is 0 - are some insurance free? or should these 0s be null instead?

# %%
#check which columns have nulls in Rate
rate.isnull().sum()
# Out:
# BusinessYear                                      0
# StateCode                                         0
# IssuerId                                          0
# SourceName                                        0
# ImportDate                                        0
# FederalTIN                                        0
# RateEffectiveDate                                 0
# RateExpirationDate                                0
# PlanId                                            0
# RatingAreaId                                      0
# Tobacco                                           0
# Age                                               0
# IndividualRate                                    0
# IndividualTobaccoRate                        245354
# Couple                                       309526
# PrimarySubscriberAndOneDependent             309526
# PrimarySubscriberAndTwoDependents            309526
# PrimarySubscriberAndThreeOrMoreDependents    309526
# CoupleAndOneDependent                        309526
# CoupleAndTwoDependents                       309526
# CoupleAndThreeOrMoreDependents               309526
# dtype: int64

# %% [markdown]
# This means that the 0s in IndividualRate are truly zero and not null. However, there are a lot of null on the other rows. Since we can't make up the data for these rates, they are probably not applicable for the specific plans. We can drop the columns with null values. Alternatively we don't have to use these rates and ony use the individual rate.

# %%
#Look at the number of plans per state
rate.loc[:,'StateCode'].value_counts()
# Out:
# FL    43022
# WI    32295
# MI    26470
# OH    25848
# TX    21247
# SC    20996
# GA    16656
# IN    14192
# IL    12851
# VA    11269
# NC    11106
# PA     7065
# NJ     5639
# OK     4412
# AL     4367
# LA     4313
# WV     4167
# MO     4102
# MT     4095
# TN     4085
# IA     3860
# KY     3390
# ME     2663
# AZ     2573
# AK     2378
# KS     2327
# ND     2226
# SD     1929
# OR     1559
# AR     1311
# UT     1156
# MS     1131
# NE     1120
# NV     1108
# WY      930
# NM      825
# NH      521
# DE      490
# HI      182
# Name: StateCode, dtype: int64

# %%
#visualise the number of plans by state
rate.loc[:,'StateCode'].value_counts().plot(kind='bar',figsize=(12,12));
plt.xlabel('State');
plt.ylabel('Number of plans');
plt.title('Number of plans per state');

# %%
#based on above graph we can see that Florida has the most plans on this sample Rate data set
#Look athe number of plans per age
rate.loc[:, 'Age'].value_counts().sort_index().plot(kind='bar', figsize=(12,12));\
plt.xlabel('Age');
plt.ylabel('Number of plans');
plt.title('Number of plans per age');

# %%
#Looking at graph above, we can see that it's almost distribute evenly across all ages except for Family option. 
# Since we are not focusing on age, we could drop records with Age = Family Option when we do the analysis
# Read Rate data into a DataFrame.
network = pd.read_csv('/Users/Barbara/Desktop/GA Data Science/Network_PUF.csv')
network.head()
# Out:
#    BusinessYear StateCode  IssuerId SourceName           ImportDate  \
# 0          2017        NC     56964       HIOS  2016-06-28 02:39:00
# 1          2017        NC     73943       HIOS  2016-08-24 02:30:21
# 2          2017        NC     76994       HIOS  2016-06-28 02:39:00
# 3          2017        NC     82612       HIOS  2016-08-16 03:04:39
# 4          2017        NC     94482       HIOS  2016-07-01 08:12:23
#
#                              NetworkName NetworkId  \
# 0            Ameritas PPO Dental Network    NCN001
# 1             North Carolina HMO Network    NCN001
# 2            Ameritas PPO Dental Network    NCN001
# 3                               DenteMax    NCN001
# 4  BEST Life and Health National Network    NCN001
#
#                                   NetworkURL MarketCoverage DentalOnlyPlan
# 0                           www.standard.com            NaN            NaN
# 1         http://www.cigna.com/ifp-providers            NaN            NaN
# 2                   www.reliancestandard.com            NaN            NaN
# 3  https://www.truassure.com/find-a-provider            NaN            NaN
# 4   http://www.bestlife.com/Provider_Search/            NaN            NaN

# %%
#Look at number of rows and columns in network data set. We didn't need to do a sample since the data set wasn't large
network.shape
# Out:
# (939, 10)

# %%
#Look at column type in network
network.dtypes
# Out:
# BusinessYear       int64
# StateCode         object
# IssuerId           int64
# SourceName        object
# ImportDate        object
# NetworkName       object
# NetworkId         object
# NetworkURL        object
# MarketCoverage    object
# DentalOnlyPlan    object
# dtype: object

# %%
#Look at  top, frequency for strings and min, max and mean for all columns in Network
network.describe(include='all')
# Out:
#         BusinessYear StateCode      IssuerId SourceName           ImportDate  \
# count          939.0       939    939.000000        939                  939
# unique           NaN        39           NaN          3                  109
# top              NaN        OH           NaN      SERFF  2016-08-20 11:23:22
# freq             NaN        61           NaN        519                   77
# mean          2017.0       NaN  53810.424920        NaN                  NaN
# std              0.0       NaN  26569.803258        NaN                  NaN
# min           2017.0       NaN  10046.000000        NaN                  NaN
# 25%           2017.0       NaN  30751.000000        NaN                  NaN
# 50%           2017.0       NaN  52391.000000        NaN                  NaN
# 75%           2017.0       NaN  76173.500000        NaN                  NaN
# max           2017.0       NaN  99969.000000        NaN                  NaN
#
#                         NetworkName NetworkId  \
# count                           939       939
# unique                          440       203
# top     Ameritas PPO Dental Network    MIN001
# freq                             80        36
# mean                            NaN       NaN
# std                             NaN       NaN
# min                             NaN       NaN
# 25%                             NaN       NaN
# 50%                             NaN       NaN
# 75%                             NaN       NaN
# max                             NaN       NaN
#
#                                       NetworkURL MarketCoverage DentalOnlyPlan
# count                                        939            542            542
# unique                                       409              2              3
# top     http://www.bestlife.com/Provider_Search/     Individual            Yes
# freq                                          42            316            282
# mean                                         NaN            NaN            NaN
# std                                          NaN            NaN            NaN
# min                                          NaN            NaN            NaN
# 25%                                          NaN            NaN            NaN
# 50%                                          NaN            NaN            NaN
# 75%                                          NaN            NaN            NaN
# max                                          NaN            NaN            NaN

# %%
network.isnull().sum()
#Will need to confirm if MarketCoverage and DentalOnlyPlan are truly nulls.
#Alternatively we could drop this columns since we don't need them for the model
# Out:
# BusinessYear        0
# StateCode           0
# IssuerId            0
# SourceName          0
# ImportDate          0
# NetworkName         0
# NetworkId           0
# NetworkURL          0
# MarketCoverage    397
# DentalOnlyPlan    397
# dtype: int64

# %%
#visualise the number of networks by state
network.loc[:,'StateCode'].value_counts().plot(kind='bar',figsize=(12,12));
plt.xlabel('State');
plt.ylabel('Number of plans');
plt.title('Number of plans per state');

# %%
# Read Benefits data into a DataFrame.
benefits = pd.read_csv('/Users/Barbara/Desktop/GA Data Science/Benefits_Cost_Sharing_PUF.csv', encoding='latin_1', dtype={'CopayInnTier2': object, 'CoinsInnTier2': object, 'Exclusions': object})
benefits = benefits.sample(frac=.1)
benefits.head()
# Out:
#          BusinessYear StateCode  IssuerId SourceName           ImportDate  \
# 172544           2017        IN     54192       HIOS  2017-01-21 03:35:28
# 197119           2017        LA     44965       HIOS  2016-08-20 07:40:33
# 931236           2017        MI     29698      SERFF  2017-04-25 20:15:31
# 345652           2017        TN     38886       HIOS  2016-07-01 08:12:23
# 1244601          2017        SD     60536      SERFF  2017-01-27 18:01:23
#
#         StandardComponentId             PlanId  \
# 172544       54192IN0010003  54192IN0010003-01
# 197119       44965LA0570033  44965LA0570033-00
# 931236       29698MI0570054  29698MI0570054-02
# 345652       38886TN0070002  38886TN0070002-01
# 1244601      60536SD0020012  60536SD0020012-01
#
#                                 BenefitName   CopayInnTier1   CopayInnTier2  \
# 172544        Non-Preferred Specialty Drugs  Not Applicable             NaN
# 197119   Emergency Transportation/Ambulance  Not Applicable  Not Applicable
# 931236                          Acupuncture          $30.00             NaN
# 345652            Major Dental Care - Adult             NaN             NaN
# 1244601              Nutritional Counseling             NaN             NaN
#
#                ...        IsEHB    IsCovered QuantLimitOnSvc LimitQty  \
# 172544         ...          NaN      Covered             NaN      NaN
# 197119         ...          Yes      Covered              No      NaN
# 931236         ...          NaN      Covered             Yes     20.0
# 345652         ...          NaN  Not Covered             NaN      NaN
# 1244601        ...          NaN  Not Covered             NaN      NaN
#
#                  LimitUnit Exclusions  \
# 172544                 NaN        NaN
# 197119                 NaN        NaN
# 931236   Visit(s) per Year        NaN
# 345652                 NaN        NaN
# 1244601                NaN        NaN
#
#                                                Explanation  EHBVarReason  \
# 172544                                                 NaN       Not EHB
# 197119                                                 NaN           NaN
# 931236   Up to 20 visits of medically managed acupunctu...       Not EHB
# 345652                                                 NaN           NaN
# 1244601                                                NaN           NaN
#
#         IsExclFromInnMOOP IsExclFromOonMOOP
# 172544                 No                No
# 197119                 No                No
# 931236                Yes               Yes
# 345652                NaN               NaN
# 1244601               NaN               NaN
#
# [5 rows x 24 columns]

# %%
#look at number of rows and columns in benefits
benefits.shape
# Out:
# (132428, 24)

# %%
#look at column types in benefits
benefits.dtypes
# Out:
# BusinessYear             int64
# StateCode               object
# IssuerId                 int64
# SourceName              object
# ImportDate              object
# StandardComponentId     object
# PlanId                  object
# BenefitName             object
# CopayInnTier1           object
# CopayInnTier2           object
# CopayOutofNet           object
# CoinsInnTier1           object
# CoinsInnTier2           object
# CoinsOutofNet           object
# IsEHB                   object
# IsCovered               object
# QuantLimitOnSvc         object
# LimitQty               float64
# LimitUnit               object
# Exclusions              object
# Explanation             object
# EHBVarReason            object
# IsExclFromInnMOOP       object
# IsExclFromOonMOOP       object
# dtype: object

# %%
#Look at  top, frequency for strings and min, max and mean for all columns in benefits
benefits.describe(include='all')
# Out:
#         BusinessYear StateCode       IssuerId SourceName           ImportDate  \
# count       132428.0    132428  132428.000000     132428               132428
# unique           NaN        39            NaN          3                  108
# top              NaN        TX            NaN       HIOS  2017-01-25 02:20:17
# freq             NaN     17042            NaN      66891                13700
# mean          2017.0       NaN   48614.654348        NaN                  NaN
# std              0.0       NaN   25310.443981        NaN                  NaN
# min           2017.0       NaN   10046.000000        NaN                  NaN
# 25%           2017.0       NaN   30751.000000        NaN                  NaN
# 50%           2017.0       NaN   37651.000000        NaN                  NaN
# 75%           2017.0       NaN   70194.000000        NaN                  NaN
# max           2017.0       NaN   99969.000000        NaN                  NaN
#
#        StandardComponentId             PlanId          BenefitName  \
# count               132428             132428               132428
# unique                5990              20262                  252
# top         60536SD0020011  91762NJ0070093-06  Orthodontia - Child
# freq                    79                 18                 2214
# mean                   NaN                NaN                  NaN
# std                    NaN                NaN                  NaN
# min                    NaN                NaN                  NaN
# 25%                    NaN                NaN                  NaN
# 50%                    NaN                NaN                  NaN
# 75%                    NaN                NaN                  NaN
# max                    NaN                NaN                  NaN
#
#          CopayInnTier1   CopayInnTier2        ...         IsEHB IsCovered  \
# count           102918           30063        ...         98750    127773
# unique             367              98        ...             1         2
# top     Not Applicable  Not Applicable        ...           Yes   Covered
# freq             59838           24456        ...         98750    102918
# mean               NaN             NaN        ...           NaN       NaN
# std                NaN             NaN        ...           NaN       NaN
# min                NaN             NaN        ...           NaN       NaN
# 25%                NaN             NaN        ...           NaN       NaN
# 50%                NaN             NaN        ...           NaN       NaN
# 75%                NaN             NaN        ...           NaN       NaN
# max                NaN             NaN        ...           NaN       NaN
#
#        QuantLimitOnSvc      LimitQty          LimitUnit  \
# count            37982  18394.000000              18394
# unique               2           NaN                 59
# top                 No           NaN  Visit(s) per Year
# freq             19949           NaN               6570
# mean               NaN    179.541209                NaN
# std                NaN   1373.806071                NaN
# min                NaN      1.000000                NaN
# 25%                NaN      1.000000                NaN
# 50%                NaN     20.000000                NaN
# 75%                NaN     40.000000                NaN
# max                NaN  75000.000000                NaN
#
#                                                Exclusions  \
# count                                               10434
# unique                                                565
# top     Coverage for certain agents or medication cate...
# freq                                                 1577
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                       Explanation         EHBVarReason  \
# count                                       40306                39684
# unique                                       2598                    7
# top     Cost share is driven by provider/setting.  Substantially Equal
# freq                                          901                21780
# mean                                          NaN                  NaN
# std                                           NaN                  NaN
# min                                           NaN                  NaN
# 25%                                           NaN                  NaN
# 50%                                           NaN                  NaN
# 75%                                           NaN                  NaN
# max                                           NaN                  NaN
#
#        IsExclFromInnMOOP IsExclFromOonMOOP
# count             111709            111721
# unique                 2                 3
# top                   No                No
# freq              110482             95029
# mean                 NaN               NaN
# std                  NaN               NaN
# min                  NaN               NaN
# 25%                  NaN               NaN
# 50%                  NaN               NaN
# 75%                  NaN               NaN
# max                  NaN               NaN
#
# [11 rows x 24 columns]

# %%
#Look at null values in benefits. We won't need those columns that have nulls so we can drop them when we merge all three DF
benefits.isnull().sum()
# Out:
# BusinessYear                0
# StateCode                   0
# IssuerId                    0
# SourceName                  0
# ImportDate                  0
# StandardComponentId         0
# PlanId                      0
# BenefitName                 0
# CopayInnTier1           29510
# CopayInnTier2          102365
# CopayOutofNet           29510
# CoinsInnTier1           29510
# CoinsInnTier2          102365
# CoinsOutofNet           29510
# IsEHB                   33678
# IsCovered                4655
# QuantLimitOnSvc         94446
# LimitQty               114034
# LimitUnit              114034
# Exclusions             121994
# Explanation             92122
# EHBVarReason            92744
# IsExclFromInnMOOP       20719
# IsExclFromOonMOOP       20707
# dtype: int64

# %%
#visualise the number of networks by state
benefits.loc[:,'StateCode'].value_counts().plot(kind='bar',figsize=(12,12));
plt.xlabel('State');
plt.ylabel('Number of benefits');
plt.title('Number of benefits per state');

# %%
#count the number of benefits per Plan Id (after some invistigation because I couldn't merge Plan with Rates, I found that 
#'StandardComponendId' is actually the 'PlanId')
benefits_count = benefits.loc[:,'StandardComponentId'].value_counts().to_frame('benefits_count')
benefits_count.index.names = ['StandardComponentId']
#make'PlanId' a column in the new dataframe so it can be joined later to rates
benefits_count['PlanId'] = benefits_count.index
benefits_count
# Out:
#                      benefits_count          PlanId
# StandardComponentId
# 60536SD0020011                   79  60536SD0020011
# 27833IL0150004                   73  27833IL0150004
# 87571OK0350051                   73  87571OK0350051
# 36096IL0990035                   69  36096IL0990035
# 41921VA0020005                   69  41921VA0020005
# 83761GA0040017                   67  83761GA0040017
# 87571OK0350035                   67  87571OK0350035
# 87416WI0010056                   66  87416WI0010056
# 11269WY0170009                   66  11269WY0170009
# 41921VA0020014                   66  41921VA0020014
# 60829MI0190002                   66  60829MI0190002
# 99248TN0060015                   66  99248TN0060015
# 32673TX0690008                   66  32673TX0690008
# 36194FL0080021                   66  36194FL0080021
# 93187VA0060026                   66  93187VA0060026
# 49046GA0410034                   66  49046GA0410034
# 62141AR0100008                   65  62141AR0100008
# 99248TN0060003                   65  99248TN0060003
# 62141AR0080008                   65  62141AR0080008
# 62141AR0080007                   65  62141AR0080007
# 52697WI0010002                   65  52697WI0010002
# 41047OH0020020                   65  41047OH0020020
# 29698MI0570054                   64  29698MI0570054
# 38599VA0040003                   64  38599VA0040003
# 68781UT0020026                   64  68781UT0020026
# 44794NE0030007                   64  44794NE0030007
# 93332GA0710004                   64  93332GA0710004
# 87416WI0010057                   64  87416WI0010057
# 27833IL0150002                   64  27833IL0150002
# 33602TX0770053                   64  33602TX0770053
# ...                             ...             ...
# 80627OH0150023                    1  80627OH0150023
# 93236ND0030001                    1  93236ND0030001
# 91920IN0020011                    1  91920IN0020011
# 84254MS0020003                    1  84254MS0020003
# 79597WI0040003                    1  79597WI0040003
# 34210WI0020003                    1  34210WI0020003
# 47822MI0010005                    1  47822MI0010005
# 15560MI0650002                    1  15560MI0650002
# 37576NC0010012                    1  37576NC0010012
# 86728OH0290005                    1  86728OH0290005
# 24601TN0020003                    1  24601TN0020003
# 74819AK0020004                    1  74819AK0020004
# 75719NV0020004                    1  75719NV0020004
# 60600IL0010004                    1  60600IL0010004
# 47540ME0030002                    1  47540ME0030002
# 97596OH0580001                    1  97596OH0580001
# 49374MS0010002                    1  49374MS0010002
# 15720NJ0060002                    1  15720NJ0060002
# 47540ME0040002                    1  47540ME0040002
# 97725FL0040006                    1  97725FL0040006
# 92498SC0010011                    1  92498SC0010011
# 17911NM0090002                    1  17911NM0090002
# 31319VA0010003                    1  31319VA0010003
# 31319VA0020011                    1  31319VA0020011
# 74056LA0010001                    1  74056LA0010001
# 12846TX0210002                    1  12846TX0210002
# 80132WY0020002                    1  80132WY0020002
# 34968OH0180001                    1  34968OH0180001
# 32753MO0830004                    1  32753MO0830004
# 48333OH0030002                    1  48333OH0030002
#
# [5990 rows x 2 columns]

# %%
#same process with network except the count should be at the issuer level
network_count = network.loc[:,'IssuerId'].value_counts().to_frame('network_count')
network_count.index.names = ['IssuerId']
#create issuerid as a column in the dataframe
network_count['IssuerId'] = network_count.index
network_count
# Out:
#           network_count  IssuerId
# IssuerId
# 18973                10     18973
# 36096                10     36096
# 99969                 9     99969
# 48396                 8     48396
# 36239                 7     36239
# 18350                 7     18350
# 16322                 7     16322
# 87571                 7     87571
# 93332                 6     93332
# 10207                 6     10207
# 23603                 6     23603
# 98185                 6     98185
# 35783                 6     35783
# 29276                 6     29276
# 17575                 6     17575
# 15560                 6     15560
# 40308                 5     40308
# 49046                 5     49046
# 33602                 5     33602
# 38166                 5     38166
# 54965                 5     54965
# 91762                 5     91762
# 11512                 5     11512
# 15614                 5     15614
# 88380                 5     88380
# 30751                 5     30751
# 20129                 5     20129
# 48963                 5     48963
# 93187                 5     93187
# 36194                 4     36194
# ...                 ...       ...
# 95865                 1     95865
# 75395                 1     75395
# 56964                 1     56964
# 35801                 1     35801
# 98899                 1     98899
# 62033                 1     62033
# 51791                 1     51791
# 71246                 1     71246
# 77352                 1     77352
# 24106                 1     24106
# 64353                 1     64353
# 83502                 1     83502
# 24112                 1     24112
# 81457                 1     81457
# 95796                 1     95796
# 86584                 1     86584
# 66105                 1     66105
# 25440                 1     25440
# 56891                 1     56891
# 19005                 1     19005
# 79422                 1     79422
# 59968                 1     59968
# 75329                 1     75329
# 66115                 1     66115
# 84033                 1     84033
# 75321                 1     75321
# 74313                 1     74313
# 20069                 1     20069
# 73292                 1     73292
# 48129                 1     48129
#
# [543 rows x 2 columns]

# %%
#obtain columns wanted from rate
individualRate = rate.loc[:,['PlanId','IssuerId', 'IndividualRate','StateCode','RatingAreaId', 'Tobacco', 'Age']]
individualRate.head()
# Out:
#                  PlanId  IssuerId  IndividualRate StateCode    RatingAreaId  \
# 2757128  80627OH0150043     80627           32.38        OH   Rating Area 3
# 60734    68707AL0040002     68707            0.00        AL  Rating Area 10
# 167225   16842FL0070122     16842          296.64        FL  Rating Area 33
# 2320950  15560MI0450002     15560           23.29        MI   Rating Area 2
# 2542863  45550NE0090001     45550            0.00        NE   Rating Area 1
#
#                                Tobacco Age
# 2757128                  No Preference  48
# 60734                    No Preference  34
# 167225   Tobacco User/Non-Tobacco User  25
# 2320950                  No Preference  30
# 2542863                  No Preference  57

# %%
#make sure there are no nulls
individualRate.isnull().sum()
# Out:
# PlanId            0
# IssuerId          0
# IndividualRate    0
# StateCode         0
# RatingAreaId      0
# Tobacco           0
# Age               0
# dtype: int64

# %%
#next we can merge our data
combined_data = pd.merge(individualRate, benefits_count)
combined_data = pd.merge(combined_data, network_count)
combined_data.head()
# Out:
#            PlanId  IssuerId  IndividualRate StateCode    RatingAreaId  \
# 0  80627OH0150043     80627           32.38        OH   Rating Area 3
# 1  80627OH0150043     80627           32.38        OH  Rating Area 14
# 2  80627OH0150043     80627           32.38        OH  Rating Area 17
# 3  80627OH0150043     80627           32.38        OH  Rating Area 16
# 4  80627OH0150043     80627           32.38        OH   Rating Area 3
#
#          Tobacco Age  benefits_count  network_count
# 0  No Preference  48               1              2
# 1  No Preference  56               1              2
# 2  No Preference  22               1              2
# 3  No Preference  50               1              2
# 4  No Preference  62               1              2

# %%
#make sure there are no nulls
combined_data.isnull().sum()
# Out:
# PlanId            0
# IssuerId          0
# IndividualRate    0
# StateCode         0
# RatingAreaId      0
# Tobacco           0
# Age               0
# benefits_count    0
# network_count     0
# dtype: int64

# %%
combined_data.shape
# Out:
# (258549, 9)

# %%
combined_data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A106A227F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A106B16B00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A106B55160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A106B88860>]], dtype=object)

# %%
# Are number of benefits and number of networks correlated?
combined_data.plot(kind='scatter', x='benefits_count', y='IndividualRate');

# %%
# Are number of network and number of networks correlated?
combined_data.plot(kind='scatter', x='network_count', y='IndividualRate');
